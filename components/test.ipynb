# %%
import sys

sys.path.append( '../utils' )
from classes_and_ids import get_classes_and_ids

# %%
get_classes_and_ids()
# Out:
#        ClassCode                                        Description  \
# 0              1                           Продовольственные товары
# 1            1.1                                   Продукты питания
# 2          1.1.1                 Хлебобулочные изделия и крупы (НД)
# 3        1.1.1.1                                                Рис
# 4      1.1.1.1.1                                Рис шлифованный, кг
# ...          ...                                                ...
# 1152  3.12.7.3.2                                   Кремация, услуга
# 1153    3.12.7.4                     Посреднические и прочие услуги
# 1154  3.12.7.4.1  Повторное получение гербового документа в орга...
# 1155  3.12.7.4.2                   Ксерокопирование документа, лист
# 1156  3.12.7.4.3       Пользование общественным туалетом, посещение
#
#       RosstatId                                         ParentName ParentCode  \
# ...
